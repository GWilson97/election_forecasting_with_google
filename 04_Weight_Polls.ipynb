# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import io
import datetime

from election_forecasting import *

# %% [markdown]
# # Get Polling Data

# %%
# Get recent Polling data
polls = pd.read_csv("https://projects.fivethirtyeight.com/polls-page/president_polls.csv")

# %%
# Create Pollster Ratings DataFrame from 538
url = "https://raw.githubusercontent.com/fivethirtyeight/data/master/pollster-ratings/pollster-ratings.csv"
res = requests.get(url).content
pollster_rating = pd.read_csv(io.StringIO(res.decode('utf-8')))

# %%
# Get example matchup polls
polls = get_matchup(polls, pollster_rating, "Donald Trump", "Joseph R. Biden Jr.", "rep", "dem", level = "all")

# %% [markdown]
# ## Weight for Recency

# %%
# Create columns with the month and year of the polls
month_array = []
for i in range(len(polls["end_date"])):
    month_array.append(int(str(polls["end_date"][i])[5:7]))
    
year_array = []
for i in range(len(polls["end_date"])):
    year_array.append(int(str(polls["end_date"][i])[:4]))

polls["month"] = pd.Series(month_array)
polls["year"] = pd.Series(year_array)

# %%
# Get the month and year of the most recent poll
latest_poll = [polls["month"][0], polls["year"][0]]

# %%
# Convert months and year into distance in months from most recent poll
month_diff = []
for i in range(polls.shape[0]):
    months_back = latest_poll[0] - polls["month"][i]
    years_back = latest_poll[1] - polls["year"][i]
    month_diff.append(months_back + (12 * years_back))

polls["month_diff"] = pd.Series(month_diff)

# %%
# Create a weighting column for recency of polling data
polls["recency_weight"] = 1 / (polls["month_diff"] + 1)

# %% [markdown]
# ## Weight for Pollster Rating

# %%
# Create a weighting column for quality of pollster: from FiveThirtyEight
polls["pollster_weight"] = 1 / (polls["Predictive    Plus-Minus"] + 2.0)

# %%
# Create cumulative weighting column
polls["poll_weight"] = polls["pollster_weight"] * polls["recency_weight"]

# %%
# Create weighted polls columns
polls["weighted_votes_dem"] = polls["poll_weight"] * polls["votes_dem"]
polls["weighted_votes_rep"] = polls["poll_weight"] * polls["votes_rep"]

# %%
polls
# Out:
#      question_id  poll_id    stage     office_type                  pollster  \
# 0         127936    68308  general  U.S. President   Landmark Communications
# 1         127932    68307  general  U.S. President  East Carolina University
# 2         127908    68287  general  U.S. President           Morning Consult
# 3         127909    68288  general  U.S. President           Morning Consult
# 4         127910    68289  general  U.S. President           Morning Consult
# ..           ...      ...      ...             ...                       ...
# 677        93202    57543  general  U.S. President            Harper Polling
# 678        92974    57445  general  U.S. President           Emerson College
# 679        92926    57427  general  U.S. President          Glengariff Group
# 680        92597    57275  general  U.S. President     Public Policy Polling
# 681        92080    57026  general  U.S. President     Public Policy Polling
#
#               state   end_date candidate_name_rep candidate_party_rep  \
# 0           Georgia 2020-08-31       Donald Trump                 REP
# 1    North Carolina 2020-08-30       Donald Trump                 REP
# 2           Arizona 2020-08-30       Donald Trump                 REP
# 3           Georgia 2020-08-30       Donald Trump                 REP
# 4          Michigan 2020-08-30       Donald Trump                 REP
# ..              ...        ...                ...                 ...
# 677  North Carolina 2019-02-13       Donald Trump                 REP
# 678            Iowa 2019-02-02       Donald Trump                 REP
# 679        Michigan 2019-01-26       Donald Trump                 REP
# 680  North Carolina 2019-01-07       Donald Trump                 REP
# 681            Ohio 2018-11-28       Donald Trump                 REP
#
#      sample_size  ...  votes_dem  total_decided month  year month_diff  \
# 0            500  ...        202            441     8  2020          0
# 1           1101  ...        513           1049     8  2020          0
# 2            943  ...        490            886     8  2020          0
# 3           1392  ...        682           1322     8  2020          0
# 4           1424  ...        740           1338     8  2020          0
# ..           ...  ...        ...            ...   ...   ...        ...
# 677          500  ...        195            410     2  2019         18
# 678          831  ...        420            830     2  2019         18
# 679          600  ...        319            560     1  2019         19
# 680          750  ...        367            697     1  2019         19
# 681          648  ...        311            596    11  2018         21
#
#      recency_weight  pollster_weight  poll_weight  weighted_votes_dem  \
# 0          1.000000         0.500000     0.500000          101.000000
# 1          1.000000         0.370370     0.370370          190.000000
# 2          1.000000         0.333333     0.333333          163.333333
# 3          1.000000         0.333333     0.333333          227.333333
# 4          1.000000         0.333333     0.333333          246.666667
# ..              ...              ...          ...                 ...
# 677        0.052632         0.476190     0.025063            4.887218
# 678        0.052632         0.625000     0.032895           13.815789
# 679        0.050000         0.333333     0.016667            5.316667
# 680        0.050000         0.476190     0.023810            8.738095
# 681        0.045455         0.476190     0.021645            6.731602
#
#      weighted_votes_rep
# 0            119.500000
# 1            198.518519
# 2            132.000000
# 3            213.333333
# 4            199.333333
# ..                  ...
# 677            5.388471
# 678           13.486842
# 679            4.016667
# 680            7.857143
# 681            6.168831
#
# [682 rows x 27 columns]
