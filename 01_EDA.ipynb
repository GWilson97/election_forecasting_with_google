# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import Data

# %%
gen_polls = pd.read_csv("../datasets/president_polls.csv")
dem_platform = pd.read_csv("../datasets/US-Party-Dem_Platform_19.2.csv")
rep_platform = pd.read_csv("../datasets/US-Party-Rep_Platform_19.2..csv")

# %% [markdown]
# ### General Presidential

# %%
gen_polls.shape
# Out:
# (2399, 36)

# %%
gen_polls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2399 entries, 0 to 2398
# Data columns (total 36 columns):
# question_id                  2399 non-null int64
# poll_id                      2399 non-null int64
# cycle                        2399 non-null int64
# state                        1227 non-null object
# pollster_id                  2399 non-null int64
# pollster                     2399 non-null object
# sponsor_ids                  914 non-null object
# sponsors                     914 non-null object
# display_name                 2399 non-null object
# pollster_rating_id           2399 non-null int64
# pollster_rating_name         2399 non-null object
# fte_grade                    2251 non-null object
# sample_size                  2399 non-null int64
# population                   2399 non-null object
# population_full              2399 non-null object
# methodology                  2397 non-null object
# office_type                  2399 non-null object
# ...

# %%
gen_polls.sample(5)
# Out:
#       question_id  poll_id  cycle          state  pollster_id  \
# 441        111155    62228   2020     California          460
# 2223        93284    57574   2020  New Hampshire         1102
# 1056       100770    58930   2020       Colorado         1102
# 597        111091    59899   2020            NaN          573
# 1350        99487    58695   2020            NaN          399
#
#                                       pollster  sponsor_ids  \
# 441                                  SurveyUSA  443,583,804
# 2223                           Emerson College          NaN
# 1056                           Emerson College          NaN
# 597             Zogby Interactive/JZ Analytics          NaN
# 1350  Rasmussen Reports/Pulse Opinion Research          NaN
#
#                                                sponsors  \
# 441   KGTV-TV (California) | KABC-TV (California) | ...
# 2223                                                NaN
# ...

# %% [markdown]
# ### Democratic Platform 1948-2016

# %%
dem_platform.shape
# Out:
# (15953, 9)

# %%
dem_platform.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15953 entries, 0 to 15952
# Data columns (total 9 columns):
# year               15953 non-null int64
# id                 15953 non-null int64
# pap_majortopic     15953 non-null int64
# pap_subtopic       15953 non-null int64
# majortopic         15953 non-null int64
# subtopic           15953 non-null int64
# description        15953 non-null object
# filter_democrat    15953 non-null int64
# words              15953 non-null int64
# dtypes: int64(8), object(1)
# memory usage: 1.1+ MB

# %%
dem_platform.sample(5)
# Out:
#        year     id  pap_majortopic  pap_subtopic  majortopic  subtopic  \
# 2156   1964   2118              19          1929          19      1929
# 5288   1976   5253               4           402           4       402
# 4143   1972   4107              13          1301          13      1302
# 14091  2012  14085               0          -555           0      -555
# 2392   1964   2354               4           400           4       400
#
#                                              description  filter_democrat  \
# 2156   Nine thousand have served in a total of 45 cou...                1
# 5288       revitalize basic credit programs for farmers;                1
# 4143   Continue with full federal funding the breakfa...                1
# 14091              Strengthening the American Community                 1
# 2392   In 1960, we saidíï"In every way we will seek...                1
#
#        words
# 2156      10
# 5288       6
# 4143      22
# 14091      4
# 2392      33

# %% [markdown]
# ### Republican Platform 1948-2016

# %%
rep_platform.shape
# Out:
# (19836, 8)

# %%
rep_platform.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19836 entries, 0 to 19835
# Data columns (total 8 columns):
# year              19836 non-null int64
# id                19836 non-null int64
# pap_majortopic    19836 non-null int64
# pap_subtopic      19836 non-null int64
# majortopic        19836 non-null int64
# subtopic          19836 non-null int64
# description       19836 non-null object
# words             19836 non-null int64
# dtypes: int64(7), object(1)
# memory usage: 1.2+ MB

# %%
rep_platform.sample(5)
# Out:
#       year    id  pap_majortopic  pap_subtopic  majortopic  subtopic  \
# 9617  1992  9543               6           607           6       607
# 398   1952   310               4           498           4       498
# 4421  1976  4340               4           401           4       401
# 8078  1988  8001              14          1409          14      1409
# 5066  1980  4987               1           100           1       100
#
#                                             description  words
# 9617  that American children should be first in the ...     13
# 398   We recommend expanded agricultural research an...     42
# 4421  We shall not permit concessional sales of agri...     33
# 8078  [p.31] «í_í_í_í_í_í_í_í_í_í_í_ W...     16
# 5066  Republicans are committed to an economic polic...     19

# %%
rep_platform.loc[rep_platform["year"] > 1950]
# Out:
#        year     id  pap_majortopic  pap_subtopic  majortopic  subtopic  \
# 0      1976   3740               2           202           2       202
# 1      1976   3823               2           202           2       202
# 2      1976   3825               2           202           2       202
# 3      1976   3826               2           202           2       202
# 4      1976   3829               2           202           2       202
# ...     ...    ...             ...           ...         ...       ...
# 19831  2016  19832              19          1925          19      1925
# 19832  2016  19833              19          1925          19      1925
# 19833  2016  19834              19          1925          19      1925
# 19834  2016  19835              18          1803          18      1803
# 19835  2016  19836              19          1929          19      1929
#
#                                              description  words
# ...
