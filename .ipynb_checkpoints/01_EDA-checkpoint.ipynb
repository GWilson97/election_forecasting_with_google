# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import Data

# %%
gen_polls = pd.read_csv("datasets/president_polls.csv")

# %% [markdown]
# ### General Presidential

# %%
gen_polls.shape
# Out:
# (2583, 36)

# %%
gen_polls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2583 entries, 0 to 2582
# Data columns (total 36 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   question_id                2583 non-null   int64
#  1   poll_id                    2583 non-null   int64
#  2   cycle                      2583 non-null   int64
#  3   state                      1323 non-null   object
#  4   pollster_id                2583 non-null   int64
#  5   pollster                   2583 non-null   object
#  6   sponsor_ids                994 non-null    object
#  7   sponsors                   994 non-null    object
#  8   display_name               2583 non-null   object
#  9   pollster_rating_id         2579 non-null   float64
#  10  pollster_rating_name       2579 non-null   object
#  11  fte_grade                  2431 non-null   object
#  12  sample_size                2583 non-null   int64
#  13  population                 2583 non-null   object
#  14  population_full            2583 non-null   object
#  15  methodology                2581 non-null   object
#  16  office_type                2583 non-null   object
#  17  seat_number                2583 non-null   int64
#  18  seat_name                  0 non-null      float64
#  19  start_date                 2583 non-null   object
#  20  end_date                   2583 non-null   object
#  21  election_date              126 non-null    object
#  22  sponsor_candidate          8 non-null      object
#  23  internal                   2583 non-null   bool
#  24  partisan                   31 non-null     object
#  25  tracking                   0 non-null      float64
#  26  nationwide_batch           2583 non-null   bool
#  27  ranked_choice_reallocated  2583 non-null   bool
#  28  created_at                 2583 non-null   object
#  29  notes                      48 non-null     object
#  30  url                        2583 non-null   object
#  31  stage                      2583 non-null   object
#  32  answer                     2583 non-null   object
#  33  candidate_name             2583 non-null   object
#  34  candidate_party            2583 non-null   object
#  35  pct                        2583 non-null   float64
# dtypes: bool(3), float64(4), int64(6), object(23)
# memory usage: 673.6+ KB

# %%
gen_polls.sample(5)
# Out:
#       question_id  poll_id  cycle           state  pollster_id  \
# 1921        94511    58085   2020             NaN          590
# 1481       100095    58795   2020             NaN         1416
# 709        104344    60063   2020  North Carolina         1516
# 473        112653    62551   2020  North Carolina         1424
# 2066        94221    57947   2020       Wisconsin          573
#
#                                           pollster sponsor_ids  \
# 1921  Fox News/Beacon Research/Shaw & Co. Research         NaN
# 1481                   Harris Insights & Analytics         985
# 709                       East Carolina University         NaN
# 473            Siena College/New York Times Upshot         NaN
# 2066                Zogby Interactive/JZ Analytics         NaN
#
#                 sponsors                         display_name  \
# 1921                 NaN                             Fox News
# 1481  ScottRasmussen.com                              HarrisX
# 709                  NaN             East Carolina University
# 473                  NaN  Siena College/New York Times Upshot
# 2066                 NaN                      Zogby Analytics
#
#       pollster_rating_id  ... nationwide_batch ranked_choice_reallocated  \
# 1921               103.0  ...            False                     False
# 1481               133.0  ...            False                     False
# 709                523.0  ...            False                     False
# 473                448.0  ...            False                     False
# 2066               395.0  ...            False                     False
#
#           created_at notes                                                url  \
# 1921   5/16/19 19:33   NaN  https://www.foxnews.com/politics/fox-news-poll...
# 1481    8/2/19 10:32   NaN   https://scottrasmussen.com/crosstabs-july-26-27/
# 709   10/14/19 14:37   NaN  https://surveyresearch.ecu.edu/wp-content/pv-u...
# 473    11/4/19 08:40   NaN  https://github.com/ndcohn/battleground-poll-20...
# 2066   4/24/19 16:02   NaN  https://zogbyanalytics.com/news/886-the-zogby-...
#
#         stage  answer    candidate_name  candidate_party    pct
# 1921  general  Warren  Elizabeth Warren              DEM  43.00
# 1481  general   Trump      Donald Trump              REP  38.00
# 709   general   Trump      Donald Trump              REP  47.70
# 473   general   Trump      Donald Trump              REP  47.57
# 2066  general   Trump      Donald Trump              REP  42.00
#
# [5 rows x 36 columns]
